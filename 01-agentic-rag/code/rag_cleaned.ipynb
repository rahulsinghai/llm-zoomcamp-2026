# %%
from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
openai_client = OpenAI()

# %%
documents = load_faq_data()
index = build_index(documents)

assistant = RAGBase(index, openai_client)

# %%
assistant.rag('I just discovered the course, can I still join?')
# Out:
# 'Yes, you can still join. If you want a certificate, make sure to submit your project while submissions are still being accepted.'

# %% [markdown]
# We don't need to pass `instructions` - the default from `rag_helper.py` is used.
#
# You can override it if you want different behavior:

# %%
custom_instructions = """
You're a course teaching assistant.
Answer the QUESTION based on the CONTEXT from the FAQ database.
Use only the facts from the CONTEXT when answering the QUESTION.
""".strip()

assistant = RAGBase(
    index=index,
    llm_client=openai_client,
    instructions=custom_instructions,
)

# %%
assistant.rag("How do I get a certificate?")
# Out:
# 'You can get a certificate only if you finish the course with a **live cohort**. Self-paced mode does **not** award certificates because you need to **peer-review 3 capstone projects**, and that can only be done while the course is running.\n\nAlso, to get the certificate, you need to **pass the Capstone project**. Homework is not mandatory, though it is recommended.'

# %%
assistant.rag("Can I still join the course after it started?")
